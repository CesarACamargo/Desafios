# %% [markdown]
# ### Aula 2 - Como começar um projeto com Pandas +
# ### Aula 03 - Importação de dados no Pandas + DataFrames e Series

# %%
import pandas as pd

# %% [markdown]
# #### Dataframe

# %%
diretorio_apple = "../data/apple_products_pricing_2020_2026.csv"
diretorio_student = "../data/student_burnout_dropout_dataset_2.csv"

df_apple = pd.read_csv(diretorio_apple)
df_apple
# Out:
#              Date  Platform Product_Category                   Model_Name  \
# 0      2020-09-19  Flipkart            Watch  Apple Watch Series 6 (44mm)
# 1      2020-09-20  Flipkart            Watch  Apple Watch Series 6 (44mm)
# 2      2020-09-23    Amazon            Watch  Apple Watch Series 6 (44mm)
# 3      2020-09-23    Amazon            Watch  Apple Watch Series 6 (44mm)
# 4      2020-09-24    Amazon            Watch  Apple Watch Series 6 (44mm)
# ...           ...       ...              ...                          ...
# 79995  2026-07-31  Flipkart           iPhone              iPhone 17 128GB
# 79996  2026-07-31  Flipkart           iPhone              iPhone 17 128GB
# 79997  2026-07-31    Amazon           iPhone              iPhone 17 128GB
# 79998  2026-07-31  Flipkart           iPhone              iPhone 17 128GB
# 79999  2026-07-31  Flipkart           iPhone              iPhone 17 128GB
#
#                  Condition  Launch_Price_USD  Launch_Price_INR  \
# ...

# %% [markdown]
# #### Series

# %%
type(df_apple)
# Out:
# pandas.DataFrame

# %%
type(df_apple["Platform"])
# Out:
# pandas.Series

# %% [markdown]
# ### Aula 04 - Conhecendo um DataFrame: Aprendendo a fazer perguntas

# %% [markdown]
# #### Aprendendo a perguntar

# %%
df_apple.head()
# Out:
#          Date  Platform Product_Category                   Model_Name  \
# 0  2020-09-19  Flipkart            Watch  Apple Watch Series 6 (44mm)
# 1  2020-09-20  Flipkart            Watch  Apple Watch Series 6 (44mm)
# 2  2020-09-23    Amazon            Watch  Apple Watch Series 6 (44mm)
# 3  2020-09-23    Amazon            Watch  Apple Watch Series 6 (44mm)
# 4  2020-09-24    Amazon            Watch  Apple Watch Series 6 (44mm)
#
#   Condition  Launch_Price_USD  Launch_Price_INR  Current_Price_USD  \
# 0       New               429             42042             435.81
# 1       New               429             42042             436.49
# 2       New               429             42042             422.73
# 3       New               429             42042             425.00
# 4       New               429             42042             436.22
#
#    Current_Price_INR  Discount_Pct Sale_Event  Stock_Status  Rating  \
# 0           43322.41          -1.6        NaN      In Stock     4.7
# ...

# %%
df_apple.tail()
# Out:
#              Date  Platform Product_Category       Model_Name  \
# 79995  2026-07-31  Flipkart           iPhone  iPhone 17 128GB
# 79996  2026-07-31  Flipkart           iPhone  iPhone 17 128GB
# 79997  2026-07-31    Amazon           iPhone  iPhone 17 128GB
# 79998  2026-07-31  Flipkart           iPhone  iPhone 17 128GB
# 79999  2026-07-31  Flipkart           iPhone  iPhone 17 128GB
#
#                  Condition  Launch_Price_USD  Launch_Price_INR  \
# 79995                  New               849             83202
# 79996                  New               849             83202
# 79997  Renewed/Refurbished               849             83202
# 79998  Renewed/Refurbished               849             83202
# 79999                  New               849             83202
#
#        Current_Price_USD  Current_Price_INR  Discount_Pct Sale_Event  \
# 79995             861.39           82894.76          -1.5        NaN
# 79996             832.50           81159.39           1.9        NaN
# ...

# %%
df_apple.shape
# Out:
# (80000, 14)

# %%
df_apple.columns
# Out:
# Index(['Date', 'Platform', 'Product_Category', 'Model_Name', 'Condition',
#        'Launch_Price_USD', 'Launch_Price_INR', 'Current_Price_USD',
#        'Current_Price_INR', 'Discount_Pct', 'Sale_Event', 'Stock_Status',
#        'Rating', 'Reviews_Count'],
#       dtype='str')

# %%
df_apple.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 80000 entries, 0 to 79999
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Date               80000 non-null  str
#  1   Platform           80000 non-null  str
#  2   Product_Category   80000 non-null  str
#  3   Model_Name         80000 non-null  str
#  4   Condition          80000 non-null  str
#  5   Launch_Price_USD   80000 non-null  int64
#  6   Launch_Price_INR   80000 non-null  int64
#  7   Current_Price_USD  80000 non-null  float64
#  8   Current_Price_INR  80000 non-null  float64
#  9   Discount_Pct       80000 non-null  float64
#  10  Sale_Event         6649 non-null   str
#  11  Stock_Status       80000 non-null  str
#  12  Rating             80000 non-null  float64
#  13  Reviews_Count      80000 non-null  int64
# dtypes: float64(4), int64(3), str(7)
# memory usage: 8.5 MB

# %%
df_apple.describe()
# Out:
#        Launch_Price_USD  Launch_Price_INR  Current_Price_USD  \
# count      80000.000000      80000.000000       80000.000000
# mean         963.959125      94467.994250         782.769855
# std          470.086413      46068.468464         461.673970
# min          329.000000      32242.000000         109.930000
# 25%          599.000000      58702.000000         432.930000
# 50%          799.000000      78302.000000         699.740000
# 75%         1199.000000     117502.000000         989.112500
# max         1999.000000     195902.000000        2038.970000
#
#        Current_Price_INR  Discount_Pct        Rating  Reviews_Count
# count       80000.000000  80000.000000  80000.000000   80000.000000
# mean        74628.342439     21.418826      4.450099    2405.995925
# std         45117.872172     16.697310      0.269782    1973.630852
# min          9157.680000     -2.000000      3.800000      10.000000
# 25%         41686.835000      6.700000      4.300000     896.000000
# ...

# %%
df_apple["Platform"].describe()
# Out:
# count        80000
# unique           2
# top       Flipkart
# freq         40043
# Name: Platform, dtype: object

# %%
df_apple.dtypes
# Out:
# Date                     str
# Platform                 str
# Product_Category         str
# Model_Name               str
# Condition                str
# Launch_Price_USD       int64
# Launch_Price_INR       int64
# Current_Price_USD    float64
# Current_Price_INR    float64
# Discount_Pct         float64
# Sale_Event               str
# Stock_Status             str
# Rating               float64
# Reviews_Count          int64
# dtype: object

# %%
df_apple.sample(5)
# Out:
#              Date  Platform Product_Category               Model_Name  \
# 35831  2024-10-14    Amazon           iPhone          iPhone 15 128GB
# 70644  2026-03-24    Amazon           iPhone          iPhone 17 128GB
# 66696  2026-01-27    Amazon           iPhone  iPhone 13 Pro Max 256GB
# 65095  2026-01-05    Amazon           iPhone  iPhone 15 Pro Max 256GB
# 19964  2023-11-02  Flipkart             iPad  iPad Air (5th Gen) 64GB
#
#                  Condition  Launch_Price_USD  Launch_Price_INR  \
# 35831                  New               799             78302
# 70644  Renewed/Refurbished               849             83202
# 66696  Renewed/Refurbished              1199            117502
# 65095                  New              1199            117502
# 19964  Renewed/Refurbished               599             58702
#
#        Current_Price_USD  Current_Price_INR  Discount_Pct  \
# 35831             534.21           52461.13          33.1
# ...

# %%
df_apple.index
# Out:
# RangeIndex(start=0, stop=80000, step=1)

# %%
df_apple.nunique()
# Out:
# Date                  2130
# Platform                 2
# Product_Category         4
# Model_Name              31
# Condition                2
# Launch_Price_USD         9
# Launch_Price_INR         9
# Current_Price_USD    49611
# Current_Price_INR    79626
# Discount_Pct           695
# Sale_Event               4
# Stock_Status             3
# Rating                  12
# Reviews_Count         8698
# dtype: int64

# %%
df_apple.isnull().sum()
# Out:
# Date                     0
# Platform                 0
# Product_Category         0
# Model_Name               0
# Condition                0
# Launch_Price_USD         0
# Launch_Price_INR         0
# Current_Price_USD        0
# Current_Price_INR        0
# Discount_Pct             0
# Sale_Event           73351
# Stock_Status             0
# Rating                   0
# Reviews_Count            0
# dtype: int64

# %%
df_apple.memory_usage().sum()
# Out:
# np.int64(8960132)

# %%
len(df_apple)
# Out:
# 80000
